# %%
# import
from rohan.global_imports import *
from rohan.dandage.figs.figure import *
# %run plots.py

# %% [markdown]
# ## Figure EV1

# %%
from rohan.dandage.plot.colors import reset_legend_colors
funs=[
## panel
plot_hist_dcs_cs_mean_cs1_essential_or_notnon_essential_or_notdriver_or_notoncogene_or_nottumor_suppressor_or_not,
## panel
plot_hist_dcs_cs_mean_cs2_essential_or_notnon_essential_or_notdriver_or_notoncogene_or_nottumor_suppressor_or_not,
## panel
plot_hist_dcs_cs_mean_cs2_1_essential_or_notnon_essential_or_notdriver_or_notoncogene_or_nottumor_suppressor_or_not,
## panel
plot_hist_dcs_cs_mean_cs3_essential_or_notnon_essential_or_notdriver_or_notoncogene_or_nottumor_suppressor_or_not,
]

fig,axes=plt.subplots(ncols=1,nrows=4,figsize=[6,9],sharex=True)
for fun,ax in zip(funs,np.ravel(axes)):
    ax=fun(ax=ax)
    leg=ax.legend(bbox_to_anchor=[1,1])
    leg=reset_legend_colors(leg)
    leg=ax.legend(bbox_to_anchor=[1,1])
#     break
labelsubplots(axes=np.ravel(axes),yoff=-0.1,xoff=-0.1)
plt.tight_layout()
savefig(f'figs/figure ev1',savepdf=True)

# %% [markdown]
# ## Figure S1

# %%
## figure s1
plt.figure(figsize=[4.75,4])
ax=plot_heatmap_dcs_cellineagg()
savefig("figs/figure s1")

# %% [markdown]
# ## Figure 1

# %%
fig = plt.figure(constrained_layout=True,figsize=[12,6.25])
funs=[
## panel
      plot_dist_paralog_or_singleton,
## panel
      plot_scatter_cs_paralog_or_singleton_paralog_singleton,
## panel
      plot_scatter_cs_paralog_or_singleton_paralog_singleton_paralog_unclassified,
## panel
      plot_dist_evolutionary_distance_essential_genes_in_paralog,
     ]
axes = [plt.subplot2grid((2, 5), (0, 0),colspan=4),
        plt.subplot2grid((2, 4), (1, 0)),
        plt.subplot2grid((2, 4), (1, 1)),
        plt.subplot2grid((2, 4), (1, 2)),
#         plt.subplot2grid((2, 4), (1, 3)),
       ]
for f,ax in zip(funs,axes):
    ax=f(ax=ax)
    ax.grid(True)
labelsubplots(axes=np.ravel(axes),xoff=-0.02)
plt.subplots_adjust(
    left=0.075, right=1.075, 
    bottom=0.075,top=0.95,  
                    wspace=0.5, hspace=0.35)
# plt.tight_layout()
savefig(f'figs/figure 1',tight_layout=False,savepdf=True)

# %% [markdown]
# ## Figure S2

# %%
fig,axes=plt.subplots(ncols=2,sharey=False,figsize=[6,3.25])
funs=[
    plot_scatter_cs_paralog_or_singleton_cs2_paralog_singleton,
    plot_scatter_cs_paralog_or_singleton_cs2_paralog_singleton_paralog_unclassified,
]
for f,ax in zip(funs,axes):
    ax=f(ax=ax)
    ax.grid(True)
labelsubplots(axes=np.ravel(axes))
# plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.5, hspace=0.5)
plt.tight_layout()
savefig(f'figs/Figure S2',tight_layout=False)

# %% [markdown]
# ## Figure 2

# %%
fig = plt.figure(
#     constrained_layout=True,
                 figsize=[10,8.5])
funs=[
## panel
    plot_dist_heteromer_or_not__all_ppi__mean,
## panel
    plot_scatter_cs_heteromer_or_not__all_biogrid__heteromer_not_heteromer,
## panel
    plot_scatter_cs_heteromer_or_homomer__all_biogrid__heteromer_and_homomer_homomer,
## panel
    plot_dist_ppi_type_ds_heteromer_or_not,
## panel
    plot_plot_heteromer_or_not_cell_line_wise_summary,    
     ]

axes = [plt.subplot2grid((3, 3), (0, 0),colspan=3),
        plt.subplot2grid((3, 3), (1, 0)),
        plt.subplot2grid((3, 3), (1, 1)),
        plt.subplot2grid((3, 3), (1, 2)),
        plt.subplot2grid((3, 5), (2, 1),colspan=2),
       ]

for f,ax in zip(funs,axes):
    ax=f(ax=ax)
    ax.grid(True)
    
labelsubplots(axes=np.ravel(axes))
plt.subplots_adjust(left=0.1, right=0.8,
                    bottom=0.05,top=0.95, 
                    wspace=0.5, hspace=0.5)
# plt.tight_layout()
savefig(f'figs/Figure 2',tight_layout=False)

# %% [markdown]
# ## Figure S3

# %%
fig=plt.figure(figsize=[8,3])
plot_dist_heteromer_or_not__direct_ppi__mean()
savefig('figs/Figure S3')

# %% [markdown]
# ## Figure S4

# %%
fig,axes= plt.subplots(ncols=4,nrows=4,figsize=[13,13])
axes=list(np.ravel(axes))
funs=[
    None,
    plot_scatter_cs_heteromer_or_not__direct_biogrid__heteromer_not_heteromer,
    plot_scatter_cs_heteromer_or_not__all_intact__heteromer_not_heteromer,
    plot_scatter_cs_heteromer_or_not__direct_intact__heteromer_not_heteromer,
    plot_scatter_cs_heteromer_or_not__all_biogrid__cs2_heteromer_not_heteromer,
    plot_scatter_cs_heteromer_or_not__direct_biogrid__cs2_heteromer_not_heteromer,
    plot_scatter_cs_heteromer_or_not__all_intact__cs2_heteromer_not_heteromer,
    plot_scatter_cs_heteromer_or_not__direct_intact__cs2_heteromer_not_heteromer,
    None,
    plot_scatter_cs_heteromer_or_homomer__direct_biogrid__heteromer_and_homomer_homomer,
    plot_scatter_cs_heteromer_or_homomer__all_intact__heteromer_and_homomer_homomer,
    plot_scatter_cs_heteromer_or_homomer__direct_intact__heteromer_and_homomer_homomer,
    plot_scatter_cs_heteromer_or_homomer__all_biogrid__cs2_heteromer_and_homomer_homomer,
    plot_scatter_cs_heteromer_or_homomer__direct_biogrid__cs2_heteromer_and_homomer_homomer,
    plot_scatter_cs_heteromer_or_homomer__all_intact__cs2_heteromer_and_homomer_homomer,
    plot_scatter_cs_heteromer_or_homomer__direct_intact__cs2_heteromer_and_homomer_homomer,      
     ]
for f,ax in zip(funs,axes):
    if not f is None:
        ax=f(ax=ax)
        ax.grid(True)
    else:
        ax.axis('off')
labelsubplots(axes=axes[1:8]+axes[9:16])
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.4, hspace=0.4)
savefig('figs/Figure S4',tight_layout=False)

# %% [markdown]
# ## Figure S5

# %%
fig = plt.figure(
#     constrained_layout=True,
                 figsize=[10,15])
axes=[]
axes_label=[]
for rowi in list(range(0,8,2)):
    axes_=[plt.subplot2grid((8, 5), rowicoli) for rowicoli in zip(list(np.repeat(0+rowi,5))+list(np.repeat(1+rowi,5)),
                                                              list(np.arange(5))+list(np.arange(5)))]
    axes+=list(np.ravel(axes_))
    axes_label+=[list(np.ravel(axes_))[0]]
funs=[
plot_dist_heteromer_or_not_cell_line_wise_all_biogrid_cs2_1_cs_mean_mean_opisthokonta,
plot_dist_heteromer_or_not_cell_line_wise_all_biogrid_cs2_1_cs_mean_mean_bilateria,
plot_dist_heteromer_or_not_cell_line_wise_all_biogrid_cs2_1_cs_mean_mean_chordata,
plot_dist_heteromer_or_not_cell_line_wise_all_biogrid_cs2_1_cs_mean_mean_vertebrata,
plot_dist_heteromer_or_not_cell_line_wise_all_biogrid_cs2_1_cs_mean_mean_euteleostomi,
plot_dist_heteromer_or_not_cell_line_wise_all_biogrid_cs2_1_cs_mean_mean_eutheria,
plot_dist_heteromer_or_not_cell_line_wise_all_biogrid_cs2_1_cs_mean_mean_simiiformes,
plot_dist_heteromer_or_not_cell_line_wise_all_biogrid_cs2_1_cs_mean_mean_catarrhini,
plot_dist_heteromer_or_not_cell_line_wise_all_biogrid_cs2_1_cs_mean_mean_homininae,
plot_dist_heteromer_or_not_cell_line_wise_all_biogrid_cs2_1_cs_mean_mean_homo_sapiens,    
    
plot_dist_heteromer_or_not_cell_line_wise_direct_biogrid_cs2_1_cs_mean_mean_opisthokonta,
plot_dist_heteromer_or_not_cell_line_wise_direct_biogrid_cs2_1_cs_mean_mean_bilateria,
plot_dist_heteromer_or_not_cell_line_wise_direct_biogrid_cs2_1_cs_mean_mean_chordata,
plot_dist_heteromer_or_not_cell_line_wise_direct_biogrid_cs2_1_cs_mean_mean_vertebrata,
plot_dist_heteromer_or_not_cell_line_wise_direct_biogrid_cs2_1_cs_mean_mean_euteleostomi,
plot_dist_heteromer_or_not_cell_line_wise_direct_biogrid_cs2_1_cs_mean_mean_eutheria,
plot_dist_heteromer_or_not_cell_line_wise_direct_biogrid_cs2_1_cs_mean_mean_simiiformes,
plot_dist_heteromer_or_not_cell_line_wise_direct_biogrid_cs2_1_cs_mean_mean_catarrhini,
plot_dist_heteromer_or_not_cell_line_wise_direct_biogrid_cs2_1_cs_mean_mean_homininae,
plot_dist_heteromer_or_not_cell_line_wise_direct_biogrid_cs2_1_cs_mean_mean_homo_sapiens,

plot_dist_heteromer_or_not_cell_line_wise_all_biogrid_cs2_cs_mean_mean_opisthokonta,
plot_dist_heteromer_or_not_cell_line_wise_all_biogrid_cs2_cs_mean_mean_bilateria,
plot_dist_heteromer_or_not_cell_line_wise_all_biogrid_cs2_cs_mean_mean_chordata,
plot_dist_heteromer_or_not_cell_line_wise_all_biogrid_cs2_cs_mean_mean_vertebrata,
plot_dist_heteromer_or_not_cell_line_wise_all_biogrid_cs2_cs_mean_mean_euteleostomi,
plot_dist_heteromer_or_not_cell_line_wise_all_biogrid_cs2_cs_mean_mean_eutheria,
plot_dist_heteromer_or_not_cell_line_wise_all_biogrid_cs2_cs_mean_mean_simiiformes,
plot_dist_heteromer_or_not_cell_line_wise_all_biogrid_cs2_cs_mean_mean_catarrhini,
plot_dist_heteromer_or_not_cell_line_wise_all_biogrid_cs2_cs_mean_mean_homininae,
plot_dist_heteromer_or_not_cell_line_wise_all_biogrid_cs2_cs_mean_mean_homo_sapiens,

plot_dist_heteromer_or_not_cell_line_wise_direct_biogrid_cs2_cs_mean_mean_opisthokonta,
plot_dist_heteromer_or_not_cell_line_wise_direct_biogrid_cs2_cs_mean_mean_bilateria,
plot_dist_heteromer_or_not_cell_line_wise_direct_biogrid_cs2_cs_mean_mean_chordata,
plot_dist_heteromer_or_not_cell_line_wise_direct_biogrid_cs2_cs_mean_mean_vertebrata,
plot_dist_heteromer_or_not_cell_line_wise_direct_biogrid_cs2_cs_mean_mean_euteleostomi,
plot_dist_heteromer_or_not_cell_line_wise_direct_biogrid_cs2_cs_mean_mean_eutheria,
plot_dist_heteromer_or_not_cell_line_wise_direct_biogrid_cs2_cs_mean_mean_simiiformes,
plot_dist_heteromer_or_not_cell_line_wise_direct_biogrid_cs2_cs_mean_mean_catarrhini,
plot_dist_heteromer_or_not_cell_line_wise_direct_biogrid_cs2_cs_mean_mean_homininae,
plot_dist_heteromer_or_not_cell_line_wise_direct_biogrid_cs2_cs_mean_mean_homo_sapiens ,   
    
]    
for f,ax in zip(funs,axes):
    ax=f(ax=ax)
    ax.grid(True)
# axes[4].legend(bbox_to_anchor=[1,1])    
labelsubplots(axes=axes_label)
savefig(f'figs/figure S5',tight_layout=True)

# %% [markdown]
# ## Figure 4

# %%
fig = plt.figure(
#     constrained_layout=True,
                 figsize=[8.5,10])
funs=[
## panel
    plot_heatmap_correlations_xyz_summary,
## panel
      plot_dist___of_interactions_heteromer_or_not__all_ppi_,
## panel
      plot_dist_fpkm__log2_scale__heteromer_or_not__all_ppi_,
## panel
      plot_swarm_feature_importances_pcorr_heteromer_or_not_heteromer_or_not__all_ppi_,
## panel
      plot_plot_classifier_deleteriousness_metrics_essential_or_not__cs_mean__cs_mean,
     ]

axes = [
    plt.subplot2grid((4, 3), (0, 1),colspan=2),
        plt.subplot2grid((4, 2), (1, 0),),
        plt.subplot2grid((4, 2), (1, 1),),
        plt.subplot2grid((4, 1), (2, 0),),
        plt.subplot2grid((4, 1), (3, 0),),
       ]
for axi,(f,ax) in enumerate(zip(funs,axes)):
    ax=f(ax=ax)
    ax.grid(True)
#     if axi==len(axes):
#         ax.set_ylim(0.5,1.5)
ax_=plt.subplot2grid((4, 4), (0, 0))
ax_.set_axis_off()
axes[0]=ax_
labelsubplots(axes=np.ravel(axes),xoff=-0.01)
plt.subplots_adjust(left=None, bottom=0.05, 
                    right=None, top=0.95, wspace=0.3, hspace=0.5)
# plt.tight_layout()
savefig(f'figs/Figure 4',tight_layout=False)

# %% [markdown]
# ## Figure S7

# %%
plt.figure(figsize=[8,8])
plot_heatmap_correlations_xyz_all()
savefig('figs/Figure S7')

# %% [markdown]
# ## Figure EV3

# %%
fig=plt.figure(figsize=[9.75,11])
axes = [
        plt.subplot2grid((3, 2), (0, 0),),
        plt.subplot2grid((3, 2), (0, 1),),
        plt.subplot2grid((3, 2), (1, 0),),
        plt.subplot2grid((3, 2), (1, 1),),
        plt.subplot2grid((3, 8), (2, 1),colspan=7),]
# axes+=[
#         plt.subplot2grid((8, 1), (5, 0),sharex=axes[-1]),
#         plt.subplot2grid((8, 1), (6, 0),sharex=axes[-1]),
#         plt.subplot2grid((8, 1), (7, 0),sharex=axes[-1]),
#        ]
axes=np.ravel(axes)
funs=[
## panel
plot_dist___of_interactions_paralog_or_singleton,
## panel
plot_dist_fpkm__log2_scale__paralog_or_singleton,
## panel
plot_scatter_fpkm__log2_scale__paralog_or_singleton_paralog_singleton,
## panel
plot_swarm_feature_importances_pcorr_paralog_or_singleton,
     
## panel
plot_heatmap_dists_cs_fpkm__log2_scale__mean_paralog_or_singleton,    
     ]
for f,ax in zip(funs,axes):
    ax=f(ax=ax)
    ax.grid(True)    
    
labelsubplots(axes[:5]) 
# plt.tight_layout()
plt.subplots_adjust(
    left=0.075, bottom=0.05, 
    right=0.8, top=0.975,
                   wspace=0.3, 
                    hspace=0.3,
                   )
savefig('figs/Figure ev3',tight_layout=False)

# %% [markdown]
# ## Figure S8

# %%
fig=plt.figure(figsize=[8,10])
funs=[

plot_dist___of_interactions_heteromer_or_not__direct_ppi_,
plot_dist_fpkm__log2_scale__heteromer_or_not__direct_ppi_,
plot_scatter_fpkm__log2_scale__heteromer_or_not__all_ppi__heteromer_not_heteromer,
plot_scatter_fpkm__log2_scale__heteromer_or_not__direct_ppi__heteromer_not_heteromer,

plot_swarm_feature_importances_pcorr_heteromer_or_not_heteromer_or_not__direct_ppi_,
]

axes = [
        plt.subplot2grid((3, 2), (0, 0),),
        plt.subplot2grid((3, 2), (0, 1),),
    
        plt.subplot2grid((3, 2), (1, 0),),
        plt.subplot2grid((3, 2), (1, 1),),
    
        plt.subplot2grid((3, 1), (2, 0),),    
       ]
for axi,(f,ax) in enumerate(zip(funs,axes)):
    ax=f(ax=ax)
    ax.grid(True)
labelsubplots(axes,yoff=-0.05) 
plt.tight_layout()    
savefig('figs/Figure S8')

# %% [markdown]
# ## Figure S9

# %%
fig=plt.figure(figsize=[8,12])
funs=[
plot_plot_classifier_deleteriousness_metrics_essential_or_not__cs_mean_cs1__cs_mean_cs1,
plot_plot_classifier_deleteriousness_metrics_essential_or_not__cs_mean_cs2__cs_mean_cs2,
plot_plot_classifier_deleteriousness_metrics_essential_or_not__cs_mean_cs2_1__cs_mean_cs2_1,
plot_plot_classifier_deleteriousness_metrics_essential_or_not__cs_mean_cs3__cs_mean_cs3,
plot_plot_regressor_deleteriousness_metrics_all_ppi,
plot_plot_regressor_deleteriousness_metrics_direct_ppi,
]

axes = [
        plt.subplot2grid((5, 1), (0, 0),),
        plt.subplot2grid((5, 1), (1, 0),),
        plt.subplot2grid((5, 1), (2, 0),),
        plt.subplot2grid((5, 1), (3, 0),),
        plt.subplot2grid((5, 2), (4, 0),),
        plt.subplot2grid((5, 2), (4, 1),),
       ]
for axi,(f,ax) in enumerate(zip(funs,axes)):
    ax=f(ax=ax)
    ax.grid(True)
labelsubplots(axes)     
plt.tight_layout()    
savefig('figs/Figure S9')

# %% [markdown]
# ## Figure S10

# %%
funs=[plot_dist_cs_mean__cs1__fpkm__log2_scale__mean_paralog_or_singleton,
plot_dist_cs_mean__cs2__fpkm__log2_scale__mean_paralog_or_singleton,
plot_dist_cs_mean__cs2_1__fpkm__log2_scale__mean_paralog_or_singleton,
plot_dist_cs_mean__cs3__fpkm__log2_scale__mean_paralog_or_singleton,     
]
fig,axs=plt.subplots(ncols=1,nrows=4,figsize=[8,8],sharex=True)
for f,ax in zip(funs,np.ravel(axs)):
    ax=f(ax=ax)
    ax.grid(True)
plt.tight_layout()
savefig('figs/Figure S10')

# %% [markdown]
# ## Figure 5

# %%
funs=[
## panel
    plot_contour_fpkm__log2_scale____of_interactions__log2_scale__cs_mean_ppitypeall_annotnone,
## panel
    plot_contour_fpkm__log2_scale____of_interactions__log2_scale__cs_mean_ppitypeall_annotparalog_or_singleton,
## panel
    plot_contour_fpkm__log2_scale____of_interactions__log2_scale__cs_mean_ppitypeall_annotheteromer_or_not__all_ppi_,
]
fig,axes=plt.subplots(nrows=3,ncols=1,figsize=[5,9],sharex=True)
for f,ax in zip(funs,axes):
    ax=f(ax=ax,fig=fig)
    ax.grid(True)
#     break
labelsubplots(axes=np.ravel(axes)) 
plt.subplots_adjust(left=0.15, bottom=0.05, right=0.6, top=0.95)
savefig('figs/Figure 5',tight_layout=False)

# %% [markdown]
# ## Figure EV4

# %%
funs=[
## panel
    plot_contour_fpkm__log2_scale____of_interactions__log2_scale__cs_mean_ppitypedirect_annotnone,
## panel
    plot_contour_fpkm__log2_scale____of_interactions__log2_scale__cs_mean_ppitypedirect_annotparalog_or_singleton,
## panel
    plot_contour_fpkm__log2_scale____of_interactions__log2_scale__cs_mean_ppitypedirect_annotheteromer_or_not__all_ppi_,
]
fig,axes=plt.subplots(nrows=3,ncols=1,figsize=[5,9],sharex=True)
for f,ax in zip(funs,axes):
    ax=f(ax=ax,fig=fig)
    ax.grid(True)
labelsubplots(axes=np.ravel(axes))    
plt.subplots_adjust(left=0.15, bottom=0.05, right=0.6, top=0.95)
savefig('figs/Figure_ev4',tight_layout=False)

# %% [markdown]
# ## Figure 6

# %%
fig = plt.figure(
                 figsize=[10.5,10])
funs=[
## panel
    plot_schem_asymmetry,    
## panel
    plot_dist_heteromer_or_not__all_ppi__cs_mean_paralog_p1_mrna_expression____p2_mrna_expression__heteromer_or_not__all_ppi_,
## panel
    plot_dist_assymetry_heteromer_not_heteromer,
    ]

axes = [
        plt.subplot2grid((3, 2), (0, 0)),
        plt.subplot2grid((3, 2), (0, 1)),

        
        plt.subplot2grid((3, 2), (2, 0)),

       ]
for fi,(f,ax) in enumerate(zip(funs,axes)):
    ax=f(ax=ax)
    if fi!=0: 
        ax.grid(True)
#         ax.legend(bbox_to_anchor=[1,1])

funs_assymetry=[
## panel
plot_plot_assymetry_cs2_1_all_ppi_heteromer,
plot_plot_assymetry_cs2_1_all_ppi_not_heteromer,
plot_plot_assymetry_cs2_all_ppi_heteromer,
plot_plot_assymetry_cs2_all_ppi_not_heteromer,
]
ax_asymmetry=plt.subplot2grid((3, 1), (1, 0))
for f in funs_assymetry:
    ax=f(ax=ax_asymmetry)
    ax.legend(bbox_to_anchor=[1,1])
    ax.grid(True)

ax_sca=plt.subplot2grid((3, 2), (2, 1))    
ax=scatter_overlap(ax=ax_sca,
        funs=[
## panel
        plot_scatter_cs_mean__cs1____of_interface_residues,
        plot_scatter_cs_mean__cs2____of_interface_residues,
        plot_scatter_cs_mean__cs2_1____of_interface_residues,
        plot_scatter_cs_mean__cs3____of_interface_residues,
        ]
        )

labelsubplots(axes=axes[:2]+[ax_asymmetry]+[axes[-1]]+[ax_sca])
# plt.subplots_adjust(
#     left=0.1, bottom=0.2, right=0.9, top=0.95,
#                    wspace=0, 
#                     hspace=0.3
#                    )
savefig('figs/Figure 6',tight_layout=True)

# %% [markdown]
# ## Figure EV5

# %%
fig = plt.figure(figsize=[9,7])
axs=[plt.subplot2grid((3, 3), (0, 2)),
     plt.subplot2grid((3, 3), (1, 2)),
     plt.subplot2grid((3, 3), (2, 2)),     
]
ax_b=plt.subplot2grid((5, 3), (0, 0),rowspan=2)

## panel
ax_b=plot_plot_asymmetry_bins_fraction_cs_cs2_1(ax=ax_b,fig=fig)

funs=[    
## panel
    plot_dist_assymetry_corr_heteromer_or_not__all_ppi__cs2_1,
## panel
    plot_dist_paralog_expression_corr_p1_rna_expression__p2_rna_expression___regular_correlation_,
## panel
    plot_dist_paralog_expression_corr_p1_protein_expression__p2_protein_expression___partial_correlation_,
]
for fi,(f,ax) in enumerate(zip(funs,axs)):
    ax=f(ax=ax)
    ax.grid(True)

    
labelsubplots(axes=[ax_b]+axs,yoff=0.05)
plt.subplots_adjust(
        left=0.1, right=0.8,
        bottom=0.05,top=0.9,
                    hspace=0.5,
                    wspace=0
                   )
# plt.tight_layout()
savefig('figs/Figure EV5',tight_layout=False)

# %% [markdown]
# ## Figure S11

# %%
fig,ax=plt.subplots(ncols=1,nrows=1)
ax=plot_dist_heteromer_or_not__direct_ppi__cs_mean_paralog_p1_mrna_expression____p2_mrna_expression__heteromer_or_not__direct_ppi_(ax=ax)
ax.grid(True)
savefig('figs/Figure S11')

# %% [markdown]
# ## Figure S12

# %%
fig = plt.figure(figsize=[6,4])
ax=plot_plot_asymmetry_bins_fraction_cs_cs2(ax=None,fig=fig)    
ax.grid(True)
plt.subplots_adjust(
    left=0.1, right=0.8,
    bottom=0.5,  top=0.95,
#                    wspace=0.5, 
                    hspace=0.75
                   )
savefig('figs/Figure S12',tight_layout=False)

# %% [markdown]
# ## Figure S13

# %%
funs_asymm=[plot_plot_assymetry_cs2_1_direct_ppi_heteromer,
plot_plot_assymetry_cs2_1_direct_ppi_not_heteromer,
plot_plot_assymetry_cs2_direct_ppi_heteromer,
plot_plot_assymetry_cs2_direct_ppi_not_heteromer,]
fig,axes=plt.subplots(nrows=2,ncols=1,figsize=[8,6])
for f in funs_asymm:
    ax=f(ax=axes[0])
    ax.legend(bbox_to_anchor=[1,1])
    ax.grid(True)    
ax=plot_dist_assymetry_corr_heteromer_or_not__all_ppi__cs2(ax=axes[1])
labelsubplots(axes)
savefig('figs/Figure S13')

# %% [markdown]
# # Figure S14

# %%
fig,axes=plt.subplots(nrows=2,ncols=4,figsize=[10,5.5])

funs=[
    plot_scatter_asymmetry_p1_mrna_expression_p1_mrna_expression_ubqln1_ubqln4_cs2_1,
    plot_scatter_asymmetry_p1_mrna_expression_p1_mrna_expression_lmna_lmnb1_cs2_1,
    plot_scatter_asymmetry_p1_mrna_expression_p1_mrna_expression_snx17_snx31_cs2_1,
    plot_scatter_asymmetry_p1_mrna_expression_p1_mrna_expression_spta1_sptan1_cs2_1,
    
        plot_scatter_asymmetry_p1_mrna_expression_p1_mrna_expression_ubqln1_ubqln4_cs2,
    plot_scatter_asymmetry_p1_mrna_expression_p1_mrna_expression_lmna_lmnb1_cs2,
    plot_scatter_asymmetry_p1_mrna_expression_p1_mrna_expression_snx17_snx31_cs2,
    plot_scatter_asymmetry_p1_mrna_expression_p1_mrna_expression_spta1_sptan1_cs2,
]

for fi,(f,ax) in enumerate(zip(funs,np.ravel(axes))):
    ax=f(ax=ax,fig=fig)
    ax.grid(True)
labelsubplots(list(np.ravel(axes)))
plt.tight_layout()
savefig('figs/Figure S14')

# %% [markdown]
# ## Figure S15

# %%
fig,axes=plt.subplots(nrows=2,ncols=3,figsize=[10,8])
funs=[
plot_pdb_ubqln1_ubqln4,
plot_pdb_actb_actg1,
plot_pdb_akr7a2_akr7a3,
plot_pdb_sfn_ywhaz,
plot_pdb_rbm23_rbm39,
plot_pdb_lmna_lmnb1,]

axes=np.ravel(axes)
for fi,(f,ax) in enumerate(zip(funs,axes)):
    ax=f(ax=ax)
labelsubplots(axes)    
savefig('figs/Figure S15')
